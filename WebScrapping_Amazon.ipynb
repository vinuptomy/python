# %%
import csv
import pandas as pd
import matplotlib.pyplot as plt

file = "./data/AmazonBoysToys.csv"
df = pd.read_csv(file)

# %%
df.drop_duplicates(inplace = True)

# %%
df["Manufacturer"].fillna("NoData", inplace = True)
df["ASIN"].fillna("NoData", inplace = True)
df["TotalReviews"].fillna("NoData", inplace = True)
df["TotalReviews"].fillna("NoData", inplace = True)
df['TotalReviews'] = df['TotalReviews'].str.replace('[global ratings]', '')
df['ReviewScore'] = df['ReviewScore'].str.replace('[out of 5]', '')
df["ReviewScore"].fillna("0", inplace = True)
df['Price'] = df['Price'].str.replace('[$]', '')
df["Price"].fillna("0", inplace = True)
# Out:
# /tmp/ipykernel_188/3180457308.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['TotalReviews'] = df['TotalReviews'].str.replace('[global ratings]', '')
# /tmp/ipykernel_188/3180457308.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['ReviewScore'] = df['ReviewScore'].str.replace('[out of 5]', '')
# /tmp/ipykernel_188/3180457308.py:8: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Price'] = df['Price'].str.replace('[$]', '')

# %%
df["1Star"].fillna("0%", inplace = True)
df["2Star"].fillna("0%", inplace = True)
df["3Star"].fillna("0%", inplace = True)
df["4Star"].fillna("0%", inplace = True)
df["5Star"].fillna("0%", inplace = True)

# %%
## Removes special chars 
df['Title'] = df['Title'].str.replace('[#,@,&,|,:,-]', ' ') 
df['Items'] = df['Items'].str.replace('[#,@,&,|,:,-]', ' ')
# Out:
# /tmp/ipykernel_188/1354251588.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Title'] = df['Title'].str.replace('[#,@,&,|,:,-]', ' ')
# /tmp/ipykernel_188/1354251588.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Items'] = df['Items'].str.replace('[#,@,&,|,:,-]', ' ')

# %%
## conevrt to Lower case 
df['Title'] = df['Title'].str.lower()
df['Items'] = df['Items'].str.lower()

# %%
## trim end of string
df['Title'] = df['Title'].str.strip()
df['Items'] = df['Items'].str.strip()

# %%
df.to_csv('./data/AmazonBoysToysCleaned.csv')

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 322 entries, 0 to 321
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   web-scraper-order      322 non-null    object
#  1   web-scraper-start-url  322 non-null    object
#  2   Items                  322 non-null    object
#  3   Items-href             322 non-null    object
#  4   Title                  322 non-null    object
#  5   Price                  322 non-null    object
#  6   ReviewScore            322 non-null    object
#  7   ASIN                   322 non-null    object
#  8   TotalReviews           322 non-null    object
#  9   5Star                  322 non-null    object
#  10  4Star                  322 non-null    object
#  11  3Star                  322 non-null    object
#  12  2Star                  322 non-null    object
#  13  1Star                  322 non-null    object
#  14  Manufacturer           322 non-null    object
# dtypes: object(15)
# memory usage: 40.2+ KB
# None

# %%
df.head(10)
# Out:
#   web-scraper-order                              web-scraper-start-url  \
# 0      1699039237-1  https://www.amazon.com/s?k=toys+for+boys&page=...
# 1      1699039243-2  https://www.amazon.com/s?k=toys+for+boys&page=...
# 2      1699039248-3  https://www.amazon.com/s?k=toys+for+boys&page=...
# 3      1699039253-4  https://www.amazon.com/s?k=toys+for+boys&page=...
# 4      1699039265-5  https://www.amazon.com/s?k=toys+for+boys&page=...
# 5      1699039274-6  https://www.amazon.com/s?k=toys+for+boys&page=...
# 6      1699039279-7  https://www.amazon.com/s?k=toys+for+boys&page=...
# 7      1699039285-8  https://www.amazon.com/s?k=toys+for+boys&page=...
# 8      1699039306-9  https://www.amazon.com/s?k=toys+for+boys&page=...
# 9     1699039327-10  https://www.amazon.com/s?k=toys+for+boys&page=...
#
#                                                Items  \
# 0  hoperock whack a mole game for toddler toys fo...
# 1  mygoci flying orb ball 2023 upgraded magic cos...
# 2  ivoxex laser tag guns set of 4 laser tag guns ...
# 3  xixiland car seat toys baby toys 0 3 months  s...
# 4  dolanus spider toys for kids 3 4 5 6 7 8 years...
# 5  joyin toddler fire truck toy   4d led projecti...
# 6  playroute electronic brain   memory game cube ...
# 7  yinosfun 3 pack airplane launcher toy  led foa...
# 8  light up monster trucks for boys and girls  to...
# 9  kolegend remote control car for girls 50+min m...
#
#                                           Items-href  \
# 0  https://www.amazon.com/HopeRock-Light-up-Toddl...
# 1  https://www.amazon.com/MyGoci-Controlled-Boome...
# 2  https://www.amazon.com/IVOXEX-Laser-Vests-Adul...
# 3  https://www.amazon.com/XIXILAND-Stroller-Newbo...
# 4  https://www.amazon.com/Dolanus-Spider-Years-Su...
# 5  https://www.amazon.com/JOYIN-Toddler-Fire-Truc...
# 6  https://www.amazon.com/PlayRoute-Memory-Electr...
# 7  https://www.amazon.com/Yinosfun-Airplane-Launc...
# 8  https://www.amazon.com/sspa/click?ie=UTF8&spc=...
# 9  https://www.amazon.com/sspa/click?ie=UTF8&spc=...
#
#                                                Title  Price ReviewScore  \
# 0  hoperock whack a mole game for toddler toys fo...  42.99         4.7
# 1  mygoci flying orb ball 2023 upgraded magic cos...  25.60         3.9
# 2  ivoxex laser tag guns set of 4 laser tag guns ...  69.99         4.6
# 3  xixiland car seat toys baby toys 0 3 months  s...  15.99         4.2
# 4  dolanus spider toys for kids 3 4 5 6 7 8 years...  19.99
# 5  joyin toddler fire truck toy   4d led projecti...  29.99         4.2
# 6  playroute electronic brain   memory game cube ...  34.99         4.3
# 7  yinosfun 3 pack airplane launcher toy  led foa...  23.99
# 8  light up monster trucks for boys and girls  to...  11.99         4.4
# 9  kolegend remote control car for girls 50+min m...  49.99         4.3
#
#          ASIN TotalReviews 5Star 4Star 3Star 2Star 1Star Manufacturer
# 0  B0CGC5P9PQ           33    0%    0%    0%    0%    0%       NoData
# 1  B0CDLW4STR           35    0%    0%    0%    0%    0%       NoData
# 2  B09NJKF2D6          648    0%    0%    0%    0%    0%       NoData
# 3  B0CF5CYSGZ            6    0%    0%    0%    0%    0%       NoData
# 4      NoData            2    0%    0%    0%    0%    0%       NoData
# 5  B0C8BT5PYV           27    0%    0%    0%    0%    0%       NoData
# 6  B0BKN271DX          412    0%    0%    0%    3%    0%       NoData
# 7  B0CDFPGC8P            7    0%    0%    0%    0%    0%       NoData
# 8  B01N5C39CX       19,216    0%    0%    0%    0%    0%       NoData
# 9  B0BZWC7HDW          776    0%   15%    8%    3%    0%     kolegend

# %%
df.plot(kind = 'scatter', x = 'Price', y = 'ReviewScore')

plt.show()

# %%
df.plot(kind = 'scatter', x = 'Price', y = 'ReviewScore')
plt.xlim([40, 50])
plt.show()
